# %% [markdown]
# # Configs

# %%
"""
CAUTION!!!
Some libraries such as nglview does not work well in vscode.
PLEASE execute the ipynb file by ''jupyter notebook'', rather than in vscode.
"""

import os
import time
import torch
import matplotlib

import numpy as np
import mdtraj as md
import nglview as nv
import matplotlib.pyplot as plt

from tqdm import tqdm
# Out:
# Warning: importing 'simtk.openmm' is deprecated.  Import 'openmm' instead.

# %%
# NOTE: Set the follwoing variables
molecule = 'alanine'
state = 'c5'

state_file = f'./{molecule}/{state}.pdb'
IMAGE_SIZE = "400px"

# %% [markdown]
# # Visualization

# %%
state = md.load(state_file)
view = nv.show_mdtraj(state, width=IMAGE_SIZE, height=IMAGE_SIZE)
view.center()
view
# Out:
# NGLWidget()

# %%
view.download_image(filename=f"{molecule}-{state}.png", transparent=True)
